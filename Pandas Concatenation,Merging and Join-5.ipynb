# %% [markdown]
# ## Lab5.Pandas Concatenate,Merge and join

# %% [markdown]
# ### 225229138-Sowmiya B

# %%
#Import necessary Modules

# %%
import pandas as pd

# %%
north_america=pd.read_csv("north_america_2000_2010.csv",index_col=0)
south_america=pd.read_csv("south_america_2000_2010.csv",index_col=0)

# %%
north_america
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0

# %%
south_america
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009    2010
# Country
# Chile    2263  2242  2250  2235  2232  2157  2165  2128  2095  2074  2069.6

# %%
# !type north_america_2000_2010.csv
# Out:
# Country,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010
# Canada,1779,1771,1754,1740,1760,1747,1745,1741,1735,1701,1703
# Mexico,2311.2,2285.2,2271.2,2276.5,2270.6,2281,2280.6,2261.4,2258,2250.2,2242.4
# USA,1836,1814,1810,1800,1802,1799,1800,1798,1792,1767,1778

# %%
# !type south_america_2000_2010.csv
# Out:
# Country,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010
# Chile,2263,2242,2250,2235,2232,2157,2165,2128,2095,2074,2069.6

# %% [markdown]
# ### Create line graphs for our yearly labor trends in north_america

# %%
import matplotlib.pyplot as plt

# %%
north_america.plot()

# %% [markdown]
# ### Plot transposed line graph of north_americadataframe, with title "Average Labor Hours Per Year"

# %%
north_america.transpose().plot(title="Average Labor Hours Per Year")

# %% [markdown]
# ### Similarly, plot transposed south_america dataframe with title "Average Labor Hours Per Year". Output chart is shown below

# %%
south_america.transpose().plot(title="Average Labor Hours Per Year")

# %% [markdown]
# ### Conacatenate American Data

# %% [markdown]
# It’s hard to compare the average labor hours in South America versus North America. If we were able to get all
# the countries into the same data frame, it would be much easier to do this camparison.

# %% [markdown]
# ### Concatenate north_america and south_america dataframes and store result in a dataframe, americas

# %%
americas= pd.concat([north_america,south_america])

# %%
americas
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# Chile    2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0
# Chile    2074.0  2069.6

# %% [markdown]
# ### Load the additional files

# %%
americas_dfs= [americas]
for year in range(2011,2016):
    filename="./americas_{}.csv".format(year)
    df=pd.read_csv(filename,index_col=0)
    americas_dfs.append(df)

# %%
americas_dfs[1]
# Out:
#            2011
# Country
# Canada   1700.0
# Chile    2047.4
# Mexico   2250.2
# USA      1786.0

# %%
americas_dfs[2]
# Out:
#            2012
# Country
# Canada   1713.0
# Chile    2024.0
# Mexico   2225.8
# USA      1789.0

# %% [markdown]
# ### Concatenate americas and americas_dfs dataframes and store result in americas

# %%
americas=pd.concat(americas_dfs,axis=1)

# %%
americas.index.names=['country']

# %%
americas
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Chile    2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
#
#            2009    2010    2011    2012    2013    2014    2015
# country
# Canada   1701.0  1703.0  1700.0  1713.0  1707.0  1703.0  1706.0
# Chile    2074.0  2069.6  2047.4  2024.0  2015.3  1990.1  1987.5
# Mexico   2250.2  2242.4  2250.2  2225.8  2236.6  2228.4  2246.4
# USA      1767.0  1778.0  1786.0  1789.0  1787.0  1789.0  1790.0

# %%
americas.transpose().plot(title="Average Labor Hours Per Year")

# %% [markdown]
# ### Appending Data from other Continents

# %%
asia=pd.read_csv("asia_2000_2015.csv",index_col=0)
asia
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# Country
# Israel   2017  1979  1993  1974  1942  1931  1919  1931  1929  1927  1918
# Japan    1821  1809  1798  1799  1787  1775  1784  1785  1771  1714  1733
# Korea    2512  2499  2464  2424  2392  2351  2346  2306  2246  2232  2187
# Russia   1982  1980  1982  1993  1993  1989  1998  1999  1997  1974  1976
#
#          2011  2012  2013  2014  2015
# Country
# Israel   1920  1910  1867  1853  1858
# Japan    1728  1745  1734  1729  1719
# Korea    2090  2163  2079  2124  2113
# Russia   1979  1982  1980  1985  1978

# %%
europe=pd.read_csv("europe_2000_2015.csv",index_col=0)
europe.head()
# Out:
#                   2000    2001    2002    2003    2004    2005    2006  \
# Country
# Austria         1807.4  1794.6  1792.2  1783.8  1786.8  1764.0  1746.2
# Belgium         1595.0  1588.0  1583.0  1578.0  1573.0  1565.0  1572.0
# Switzerland     1673.6  1635.0  1614.0  1626.8  1656.5  1651.7  1643.2
# Czech Republic  1896.0  1818.0  1816.0  1806.0  1817.0  1817.0  1799.0
# Germany         1452.0  1441.9  1430.9  1424.8  1422.2  1411.3  1424.7
#
#                   2007    2008    2009    2010    2011    2012    2013  \
# Country
# Austria         1736.0  1728.5  1673.0  1668.6  1675.9  1652.9  1636.7
# Belgium         1577.0  1570.0  1548.0  1546.0  1560.0  1560.0  1558.0
# Switzerland     1632.7  1623.1  1614.9  1612.4  1605.4  1590.9  1572.9
# Czech Republic  1784.0  1790.0  1779.0  1800.0  1806.0  1776.0  1763.0
# Germany         1424.4  1418.4  1372.7  1389.9  1392.8  1375.3  1361.7
#
#                   2014    2015
# Country
# Austria         1629.4  1624.9
# ...

# %%
south_pacific=pd.read_csv("south_pacific_2000_2015.csv",index_col=0)
south_pacific
# Out:
#                2000    2001    2002    2003    2004    2005    2006    2007  \
# Country
# Australia    1778.7  1736.7  1731.7  1735.8  1734.5  1729.2  1720.5  1712.5
# New Zealand  1836.0  1825.0  1826.0  1823.0  1830.0  1815.0  1795.0  1774.0
#
#                2008  2009    2010    2011    2012    2013    2014  2015
# Country
# Australia    1717.2  1690  1691.5  1699.5  1678.6  1662.7  1663.6  1665
# New Zealand  1761.0  1740  1755.0  1746.0  1734.0  1752.0  1762.0  1757

# %% [markdown]
# ### Append asia,europe and south_pacific to americas dataframe and assign to new dataframe world

# %%
world=americas.append([asia,europe,south_pacific])

# %%
world.index
# Out:
# Index(['Canada', 'Chile', 'Mexico', 'USA', 'Israel', 'Japan', 'Korea',
#        'Russia', 'Austria', 'Belgium', 'Switzerland', 'Czech Republic',
#        'Germany', 'Denmark', 'Spain', 'Estonia', 'Finland', 'France',
#        'United Kingdom', 'Greece', 'Hungary', 'Ireland', 'Iceland', 'Italy',
#        'Lithuania', 'Luxembourg', 'Latvia', 'Netherlands', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Slovenia', 'Sweden', 'Australia',
#        'New Zealand'],
#       dtype='object')

# %% [markdown]
# ### Plot,transposed world dataframe

# %%
world.transpose().plot(title="Average Labor Hours Per Year")

# %% [markdown]
# ### Let us customise this plot, so that country names appear outside the chart

# %%
#Update plot() with the following features
figsize=(10,10),
colormap="rainbow",
linewidth=2,
loc="right"

# %%
world.transpose().plot(figsize=(10,10),colormap="rainbow",linewidth=2,title="Average Labor House Per Year")
plt.legend(loc="right",bbox_to_anchor=(1.3,0.5))
plt.show()

# %% [markdown]
# ### Merging Historical Labor Data

# %%
historical=pd.read_csv("historical.csv",index_col=0)
historical.head()
# Out:
#              1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# Country
# Australia     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Austria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Belgium       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Canada        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Switzerland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#               ...      1990     1991     1992     1993     1994      1995  \
# Country       ...
# Australia     ...    1779.5  1774.90  1773.70  1786.50  1797.60  1793.400
# Austria       ...       NaN      NaN      NaN      NaN      NaN  1619.200
# Belgium       ...    1662.9  1625.79  1602.72  1558.59  1558.59  1515.835
# Canada        ...    1789.5  1767.50  1766.00  1764.50  1773.00  1771.500
# Switzerland   ...       NaN  1673.10  1684.80  1685.80  1706.20  1685.500
#
#                  1996      1997     1998    1999
# ...

# %%
print("world rows & columns:", world.shape)
print("Historical rows & columns:", historical.shape)
# Out:
# world rows & columns: (36, 16)
# Historical rows & columns: (39, 50)

# %% [markdown]
# ### Merge historical dataframe with world dataframe and store in a new variable, world_historical

# %%
world_historical=pd.merge(world, historical,left_index=True,right_index=True)

# %%
world_historical.shape
# Out:
# (36, 66)

# %%
world_historical.head(5)
# Out:
#           2000    2001    2002    2003    2004    2005    2006    2007  \
# Canada  1779.0  1771.0  1754.0  1740.0  1760.0  1747.0  1745.0  1741.0
# Chile   2263.0  2242.0  2250.0  2235.0  2232.0  2157.0  2165.0  2128.0
# Mexico  2311.2  2285.2  2271.2  2276.5  2270.6  2281.0  2280.6  2261.4
# USA     1836.0  1814.0  1810.0  1800.0  1802.0  1799.0  1800.0  1798.0
# Israel  2017.0  1979.0  1993.0  1974.0  1942.0  1931.0  1919.0  1931.0
#
#           2008    2009   ...      1990     1991    1992     1993    1994  \
# Canada  1735.0  1701.0   ...    1789.5  1767.50  1766.0  1764.50  1773.0
# Chile   2095.0  2074.0   ...       NaN      NaN     NaN      NaN     NaN
# Mexico  2258.0  2250.2   ...       NaN  2283.25     NaN  2305.85     NaN
# USA     1792.0  1767.0   ...    1832.0  1820.00  1822.0  1830.50  1838.0
# Israel  1929.0  1927.0   ...       NaN      NaN     NaN      NaN     NaN
#
#            1995     1996     1997     1998    1999
# ...

# %% [markdown]
# ### Joining Historical Data

# %%
world_historical=historical.join(world)

# %%
world_historical.head()
# Out:
#              1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# Country
# Australia     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Austria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Belgium       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Canada        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Switzerland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#               ...      2006    2007    2008    2009    2010    2011    2012  \
# Country       ...
# Australia     ...    1720.5  1712.5  1717.2  1690.0  1691.5  1699.5  1678.6
# Austria       ...    1746.2  1736.0  1728.5  1673.0  1668.6  1675.9  1652.9
# Belgium       ...    1572.0  1577.0  1570.0  1548.0  1546.0  1560.0  1560.0
# Canada        ...    1745.0  1741.0  1735.0  1701.0  1703.0  1700.0  1713.0
# Switzerland   ...    1643.2  1632.7  1623.1  1614.9  1612.4  1605.4  1590.9
#
#                2013    2014    2015
# Country
# ...

# %%
world_historical.sort_index(inplace=True)

# %% [markdown]
# ### Plot,transposed world_historical dataframe

# %%
 world_historical.transpose().plot(title="Average Labor Hours Per Year")

# %%
world_historical.index.name="Country"

# %% [markdown]
# ### Which Country worked longer hours per year?

# %%
world_historical.groupby("Country").max()
# Out:
#                         1950        1951         1952     1953         1954  \
# Country
# Australia                NaN         NaN          NaN      NaN          NaN
# Austria                  NaN         NaN          NaN      NaN          NaN
# Belgium                  NaN         NaN          NaN      NaN          NaN
# Canada                   NaN         NaN          NaN      NaN          NaN
# Chile                    NaN         NaN          NaN      NaN          NaN
# Costa Rica               NaN         NaN          NaN      NaN          NaN
# Czech Republic           NaN         NaN          NaN      NaN          NaN
# Denmark                  NaN         NaN          NaN      NaN          NaN
# Estonia                  NaN         NaN          NaN      NaN          NaN
# Finland                  NaN         NaN          NaN      NaN          NaN
# France           2086.380005  2114.61499  2096.035034  2078.25  2094.825012
# ...

# %% [markdown]
# ### Which Country worked shorter hours per year?

# %%
world_historical.groupby("Country").min()
# Out:
#                         1950        1951         1952     1953         1954  \
# Country
# Australia                NaN         NaN          NaN      NaN          NaN
# Austria                  NaN         NaN          NaN      NaN          NaN
# Belgium                  NaN         NaN          NaN      NaN          NaN
# Canada                   NaN         NaN          NaN      NaN          NaN
# Chile                    NaN         NaN          NaN      NaN          NaN
# Costa Rica               NaN         NaN          NaN      NaN          NaN
# Czech Republic           NaN         NaN          NaN      NaN          NaN
# Denmark                  NaN         NaN          NaN      NaN          NaN
# Estonia                  NaN         NaN          NaN      NaN          NaN
# Finland                  NaN         NaN          NaN      NaN          NaN
# France           2086.380005  2114.61499  2096.035034  2078.25  2094.825012
# ...
