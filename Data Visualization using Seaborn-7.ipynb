# %% [markdown]
# ## Lab7.Data Visualization in Seaborn

# %% [markdown]
# #### Import necessary packages

# %%
import pandas as pd

# %% [markdown]
# ### 1.Visualizing Statistical Relationships

# %% [markdown]
# #### import train_upvote_mini.csv file

# %%
df=pd.read_csv("train_upvote_mini.csv")

# %%
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %% [markdown]
# #### What is its size?

# %%
df.shape
# Out:
# (15440, 7)

# %% [markdown]
# #### Show the types of each feature

# %%
df.dtypes
# Out:
# ID              int64
# Tag            object
# Reputation    float64
# Answers       float64
# Username        int64
# Views         float64
# Upvotes       float64
# dtype: object

# %% [markdown]
# #### How many unique "tag" available?

# %%
df["Tag"].unique()
# Out:
# array(['a', 'c', 'r', 'j', 'p', 's', 'h', 'o', 'i', 'x'], dtype=object)

# %% [markdown]
# ### Visualize with scatterplot

# %% [markdown]
# #### Does no.of.views correlate no of upvotes?

# %% [markdown]
# #### Show scatterplot (inherited from matplotlib) and relplot between "views" and "upvotes"

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['Views'], y=df['Upvotes'])
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# #### Plot replot between "Views" and "Upvotes"

# %%
import seaborn as sns
sns.relplot(data=df, x="Views", y="Upvotes")

# %% [markdown]
# ### Next we want to see the tag associated with data.

# %% [markdown]
# #### Plot relplot between "Views" and "Upvotes" with hue as "Tag"

# %%
sns.relplot(data=df, x="Views", y="Upvotes",hue='Tag')

# %% [markdown]
# ### Hue Plot

# %% [markdown]
# #### plot relplot between "Views" and "Upvotes" with hue as "Answers"

# %%
sns.relplot(data=df,x="Views",y="Upvotes",hue="Answers")

# %% [markdown]
# #### plot relplot between "Views" and "Upvotes" with size as "Tag"

# %%
sns.relplot(data=df,x="Views",y="Upvotes",size="Tag")

# %% [markdown]
# #### Does no of times question answered impact the no of upvotes?

# %% [markdown]
# #### plot line chart using relplot between "Answers" and "Upvotes".

# %%
sns.relplot(data=df,x="Answers",y="Upvotes",kind="line")

# %% [markdown]
# #### Does Reputation score of question author impact no of upvotes?. Draw relplot.

# %%
sns.relplot(data=df,x="Reputation",y="Upvotes")

# %% [markdown]
# ### 2.Visualizating Categorical Data

# %% [markdown]
# #### various categorical plots in seaborn

# %% [markdown]
# #### Jitter Plot

# %%
df2=pd.read_csv("train_hr_mini.csv")
df2.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df2.shape
# Out:
# (6397, 14)

# %% [markdown]
# #### Show jitter plot between education and avg_training_score

# %%
sns.stripplot(data=df2, x="education", y="avg_training_score", jitter=True)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Let us make jitter to False

# %%
sns.stripplot(data=df2, x="education", y="avg_training_score", jitter=False)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Swarm Plot

# %% [markdown]
# #### Plot Swarm plot between education category and avg_training_score

# %%
sns.swarmplot(data=df2,x="education",y="avg_training_score")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 74.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Hue Plot

# %% [markdown]
# #### Show Hue Plot to see the gender distribution in the plot of education category and avg_training_score.Here, hue is "gender".

# %%
sns.catplot(data=df2,x="education",y="avg_training_score",hue="gender")

# %% [markdown]
# #### Who are all promoted considering education and avg training score?. Draw swarm plot with hue as "is_promoted"

# %%
sns.swarmplot(data=df2,x="education",y="avg_training_score",hue="is_promoted")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 74.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Box plot

# %% [markdown]
# #### Draw box plot between education and avg_training_score

# %%
sns.boxplot(data=df2,x="education",y="avg_training_score")
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Box Plot with Hue Dimension

# %% [markdown]
# #### Who are promoted and not promoted considering education and avg_training_score?. Draw Box Plot.

# %%
sns.boxplot(data=df2,x="education",y="avg_training_score",hue="is_promoted")
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Violin Plot

# %% [markdown]
# #### Show violin plot between education categories and avg training score with hue as "is_promoted" target variable.

# %%
sns.violinplot(data=df2,x="education",y="avg_training_score",hue="is_promoted")
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Draw Violin plot with only 2 hue levels, use split attribute

# %%
sns.violinplot(data=df2,x="education",y="avg_training_score",hue="is_promoted",split=True)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Using catplot(), draw a Bar Chart between "education" and "avg_training_score", with hue as "is_promoted"

# %%
sns.barplot(data=df2,x="education",y="avg_training_score",hue="is_promoted")
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Point Plot

# %% [markdown]
# #### Show point plot between education and avg training score with hue promotion category

# %%
sns.pointplot(data=df2, x="education", y="avg_training_score", hue ='is_promoted')
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %% [markdown]
# #### Multiple Dimension in Seaborn

# %% [markdown]
# #### Draw swarm plot for education, avg training score, hue as is_promoted for male and female category

# %%
sns.catplot(data=df2, x="education", y="avg_training_score", hue="is_promoted", kind='swarm', col='gender', palette='Set2')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 38.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 3.Visualizing the Distribution of Data

# %% [markdown]
# ### Plot Univariate Distributions

# %% [markdown]
# #### Plot Histogram with kernel density estimate value for age attribute

# %%
sns.histplot(x='age', data=df2, kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# #### Show only Histogram for age variable, without KDE

# %%
sns.histplot(x='age', data=df2)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# ### Plot Bivariate Distributions

# %% [markdown]
# #### Joint Plot

# %% [markdown]
# #### Draw a joint plot between avg_training_score and age

# %%
sns.jointplot(x='avg_training_score',y='age', data=df2 )

# %% [markdown]
# ### Hex Plot

# %% [markdown]
# #### Draw a hexplot for depicting the relationship between avg training score and age

# %%
sns.jointplot(x='avg_training_score',y='age',kind='hex', data=df2)

# %% [markdown]
# ### KDE Plot

# %% [markdown]
# #### Show KDE Plot to visualize age vs avg training score

# %%
sns.kdeplot(x='age',y='avg_training_score', data=df2 )
# Out:
# <AxesSubplot:xlabel='age', ylabel='avg_training_score'>

# %% [markdown]
# ### Heat Map

# %% [markdown]
# #### Draw heatmap for the dataset

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Boxen Plot

# %% [markdown]
# #### Draw Boxen Plot between "age" and "avg_training_score, with hue "is_promoted"

# %% [markdown]
# #### Adjust height and aspect values to make chart pretty

# %%
sns.catplot(x='age',y='avg_training_score', data=df2, kind='boxen', height=15, aspect=.5 )

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# #### Draw a Pair Plot for the dataset

# %%
sns.pairplot(df2)
